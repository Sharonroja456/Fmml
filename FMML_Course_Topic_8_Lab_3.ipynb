# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharonroja456/Fmml/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-09 05:01:43--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  59.2MB/s    in 1.2s
#
# 2024-04-09 05:01:50 (59.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21913  1502.05312v2  Unknown constraints arise in many types of exp...  stat
# 21813   0808.2241v1  We construct a framework for studying clusteri...  stat
# 22488  1609.07410v2  The softmax representation of probabilities fo...  stat
# 12003  1706.01151v1  In this paper, we consider the use of deep neu...  stat
# 19883   1303.1504v1  A major reason behind the success of probabili...    cs
# ...             ...                                                ...   ...
# 10207  1801.01944v1  We construct targeted audio adversarial exampl...    cs
# 21258  1711.05541v4  An Oracle is a design for potentially high pow...    cs
# 6230   1610.00494v3  We consider the problem of efficient "on the f...  stat
# 5630   1505.02910v2  Transductive learning considers situations whe...  stat
# 19814   1207.4135v1  We introduce a probabilistic formalism subsumi...    cs
#
#                                                    title  year  \
# 21913  Predictive Entropy Search for Bayesian Optimiz...  2015
# 21813  Persistent Clustering and a Theorem of J. Klei...  2008
# 22488  One-vs-Each Approximation to Softmax for Scala...  2016
# 12003                                Deep MIMO Detection  2017
# 19883                     Argument Calculus and Networks  2013
# ...                                                  ...   ...
# 10207  Audio Adversarial Examples: Targeted Attacks o...  2018
# 21258                   Good and safe uses of AI Oracles  2017
# 6230   One-Trial Correction of Legacy AI Systems and ...  2016
# 5630   Permutational Rademacher Complexity: a New Com...  2015
# 19814  Case-Factor Diagrams for Structured Probabilis...  2012
#
#                                                 keywords
# 21913  [constraints, expensive, optimization, perform...
# 21813  [construct, framework, clustering, algorithms,...
# 22488  [representation, probabilities, categorical, v...
# 12003  [detection, introduction, architecture, detect...
# 19883  [probability, possesses, probabilistic, indepe...
# ...                                                  ...
# 10207  [construct, adversarial, automatic, recognitio...
# 21258  [potentially, artificial, intelligences, restr...
# 6230   [efficient, artificial, intelligence, arbitrar...
# 5630   [transductive, considers, situations, unlabell...
# 19814  [introduce, probabilistic, formalism, subsumin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21913    [constraints, expensive, optimization, perform...
# 21813    [construct, framework, clustering, algorithms,...
# 22488    [representation, probabilities, categorical, v...
# 12003    [detection, introduction, architecture, detect...
# 19883    [probability, possesses, probabilistic, indepe...
#                                ...
# 27845    [representation, potential, compressive, recon...
# 21740    [foundational, theoretical, distributed, param...
# 36467    [minimisation, functions, variables, applicati...
# 864      [multilayer, bootstrap, gradually, multilayer,...
# 33396    [multilayer, feedforward, direction, attention...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8833 words.
# Out of those 4559 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f750cb8-e41c-4fed-89c1-2a63190d6985" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f750cb8-e41c-4fed-89c1-2a63190d6985")) {                    Plotly.newPlot(                        "4f750cb8-e41c-4fed-89c1-2a63190d6985",                        [{"x":["improvement","performance","exploration","direction","decoupled","performing","pathologies","additionally","encounter","synthetic","optimization","predictive","effective","benchmark","promising","favorably","objective","expensive","computing","independently","information","pathology","heuristic","collected","approaches","constraints","demonstrate","constrained","algorithm","existence","persistent","algorithms","kleinberg","uniqueness","established","analogous","multiresolution","convergence","properties","functoriality","structure","functions","persistence","stability","clustering","framework","construct","representation","efficient","interesting","variables","inference","subsampling","instances","classification","theoretical","categorical","probabilities","prominent","recommendation","expressed","associated","introduce","stochastic","estimation","probability","approximation","applications","normalizing","including","parameters","semidefinite","architecture","numerical","competing","providing","comparison","relaxation","approximate","introduction","conditioned","detection","simulations","complexity","specified","robustness","significantly","reasoning","available","propositional","independence","databases","graphical","nonmonotonic","maintenance","diagnosis","resembles","specifically","possesses","probabilistic","describes","extension","compactly","difficult","sentences","naturally","constraint","hypotheses","generated","ambiguous","processing","segmentation","handwriting","partially","especially","segmented","recognition","consistency","represent","satisfaction","syntactically","functional","influence","uncertainty","derivation","principles","appearance","determined","technique","description","connected","geometric","formulation","identified","connectedness","photographic","considerations","expressiveness","techniques","arbitrary","calculations","corresponding","registered","annotations","modalities","semantically","annotated","development","potentially","regularities","understanding","utilizing","unsupervised","morphological","interpretability","distributions","automatic","significant","extracted","arrhythmia","heartbeat","consistent","advantages","relabeling","simplification","artifacts","reproduce","individual","descriptions","identification","meaningful","importance","elucidate","formalize","demonstrates","emphasizing","challenge","significance","fundamental","interpretation","knowledge","underlying","potential","abductive","fibrillation","asymptotically","informative","represented","investigated","processes","representations","hyperparameters","recovering","illustrate","estimator","distributed","separation","conducted","unobserved","posterior"],"y":[155,854,60,52,3,70,4,60,1,142,310,76,248,214,126,15,157,56,136,33,649,4,53,69,406,160,557,48,834,32,4,579,0,7,54,14,4,122,217,1,340,196,3,38,143,509,95,363,388,84,126,222,2,101,523,147,16,64,18,30,42,92,332,137,204,165,124,408,2,265,260,6,269,83,27,93,127,20,117,44,23,357,36,253,45,96,259,139,287,19,38,47,76,7,9,63,2,167,10,171,70,67,5,159,59,51,108,27,171,22,256,199,7,48,122,26,373,60,107,29,5,55,63,85,10,42,73,27,248,83,84,66,72,38,5,8,14,16,386,71,7,112,10,66,34,30,65,118,51,9,148,29,154,22,14,125,187,234,130,4,2,79,102,2,9,22,10,125,38,101,55,89,2,10,60,3,147,21,81,75,357,119,145,7,3,8,35,89,46,120,250,15,21,79,27,110,34,80,8,34],"type":"bar"},{"x":["improvement","performance","exploration","direction","decoupled ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4559,), (4559, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Multi</span> <span style=''>Modal</span> <span style=''>Obstacle</span> <span style='background-color:rgba(0, 255, 0, 0.5488069414316703);'>Detection</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695665);'>Unstructured</span> <span style='background-color:rgba(0, 255, 0, 0.4774774774774775);'>Environments</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Conditional</span> <span style=''>Random</span> <span style=''>Fields</span> <br/><br/><span style=''>Reliable</span> <span style=''>obstacle</span> <span style='background-color:rgba(0, 255, 0, 0.5488069414316703);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>in</span> <span style=''>rough</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.30434782608695665);'>unstructured</span> <span style=''>terrain</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>agricultural</span> <span style=''>fields</span> <span style=''>or</span> <span style=''>orchards</span> <span style=''>remains</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.43749999999999994);'>challenging</span> <span style=''>problem</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.4774774774774775);'>environments</span> <span style=''>involve</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.5090909090909091);'>variations</span> <span style=''>in</span> <span style=''>both</span> <span style=''>geometry</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.8961038961038961);'>appearance</span> <span style='background-color:rgba(0, 255, 0, 0.43749999999999994);'>challenging</span> <span style='background-color:rgba(0, 255, 0, 0.7209302325581396);'>perception</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>only</span> <span style=''>a</span> <span style=''>single</span> <span style=''>sensor</span> <span style=''>modality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Geometrically</span> <span style=''>tall</span> <span style=''>grass</span> <span style=''>fallen</span> <span style=''>leaves</span> <span style=''>or</span> <span style=''>terrain</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>roughness</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mistakenly</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>perceived</span> <span style=''>as</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traversable</span> <span style=''>or</span> <span style=''>might</span> <span style=''>even</span> <span style=''>obscure</span> <span style=''>actual</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>obstacles</span> <span style=''>Likewise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traversable</span> <span style=''>grass</span> <span style=''>or</span> <span style=''>dirt</span> <span style=''>roads</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>obstacles</span> <span style=''>such</span> <span style=''>as</span> <span style=''>trees</span> <span style=''>and</span> <span style=''>bushes</span> <span style=''>might</span> <span style=''>be</span> <span style=''>visually</span> <span style='background-color:rgba(0, 255, 0, 0.517241379310345);'>ambiguous</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>combine</span> <span style='background-color:rgba(0, 255, 0, 0.8961038961038961);'>appearance</span> <span style=''>and</span> <span style=''>geometry</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>over</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>Cardiac</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Simulators</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Performing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulators</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>as</span> <span style=''>their</span> <span style=''>runtime</span> <span style=''>means</span> <span style=''>we</span> <span style=''>cannot</span> <span style=''>compute</span> <span style=''>a</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>method</span> <span style=''>to</span> <span style=''>infer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>for</span> <span style=''>a</span> <span style=''>cardiac</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulator</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>replicates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>electrical</span> <span style=''>flow</span> <span style=''>through</span> <span style=''>the</span> <span style=''>heart</span> <span style=''>to</span> <span style=''>the</span> <span style=''>body</span> <span style=''>surface</span> <span style=''>We</span> <span style=''>improve</span> <span style=''>the</span> <span style=''>fit</span> <span style=''>of</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulator</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>electrocardiogram</span> <span style=''>(ECG)</span> <span style=''>recorded</span> <span style=''>from</span> <span style=''>a</span> <span style=''>real</span> <span style=''>patient</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Utility</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>Duality</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>duality</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3169398907103826);'>distributions</span> <span style=''>and</span> <span style=''>utility</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Compact</span> <span style=''>Multi</span> <span style=''>Class</span> <span style=''>Boosted</span> <span style=''>Trees</span> <br/><br/><span style=''>Gradient</span> <span style=''>boosted</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>are</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>in</span> <span style=''>part</span> <span style=''>because</span> <span style=''>of</span> <span style=''>their</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>give</span> <span style=''>good</span> <span style=''>accuracy</span> <span style=''>with</span> <span style=''>small</span> <span style=''>models</span> <span style=''>We</span> <span style=''>describe</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>tree</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>increase</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantage</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style=''>from</span> <span style=''>scalar</span> <span style=''>valued</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>vector</span> <span style=''>valued</span> <span style=''>trees</span> <span style=''>This</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>trees</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>rather</span> <span style=''>than</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style=''>one</span> <span style=''>tree</span> <span style=''>per</span> <span style=''>class</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>drastically</span> <span style=''>reduces</span> <span style=''>the</span> <span style=''>model</span> <span style=''>size</span> <span style=''>required</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>some</span> <span style=''>other</span> <span style=''>popular</span> <span style=''>vector</span> <span style=''>valued</span> <span style=''>gradient</span> <span style=''>boosted</span> <span style=''>trees</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modifications</span> <span style=''>fit</span> <span style=''>into</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>and</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>obtained</span> <span style=''>in</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>The</span> <span style=''>second</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>layer</span> <span style=''>by</span> <span style=''>layer</span> <span style=''>boosting</span> <span style=''>takes</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09913793103448276)
# 	experimental (0.1314655172413793)
# 	information (0.23311781609195403)
# 	segmentation (0.07147988505747127)
# 	knowledge (0.12823275862068967)
# 	architecture (0.0966235632183908)
# 	different (0.26436781609195403)
# 	detection (0.12823275862068967)
# 	convolutional (0.13829022988505746)
# 	recognition (0.13397988505747127)
#
# Some Statistics words are:
# 	algorithm (0.38392857142857145)
# 	stochastic (0.13690476190476192)
# 	statistical (0.14781746031746032)
# 	variables (0.1388888888888889)
# 	estimation (0.17063492063492064)
# 	theoretical (0.15873015873015872)
# 	distribution (0.18204365079365079)
# 	inference (0.19642857142857142)
# 	dimensional (0.19345238095238096)
# 	regression (0.1810515873015873)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b19d6ac2-4e7a-4e05-a9bb-a6866ad32acd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b19d6ac2-4e7a-4e05-a9bb-a6866ad32acd")) {                    Plotly.newPlot(                        "b19d6ac2-4e7a-4e05-a9bb-a6866ad32acd",                        [{"x":["improvement","performance","exploration","direction","decoupled","performing","pathologies","additionally","encounter","synthetic","optimization","predictive","effective","benchmark","promising","favorably","objective","expensive","computing","independently","information","pathology","heuristic","collected","approaches","constraints","demonstrate","constrained","algorithm","existence","persistent","algorithms","kleinberg","uniqueness","established","analogous","multiresolution","convergence","properties","functoriality","structure","functions","persistence","stability","clustering","framework","construct","representation","efficient","interesting","variables","inference","subsampling","instances","classification","theoretical","categorical","probabilities","prominent","recommendation","expressed","associated","introduce","stochastic","estimation","probability","approximation","applications","normalizing","including","parameters","semidefinite","architecture","numerical","competing","providing","comparison","relaxation","approximate","introduction","conditioned","detection","simulations","complexity","specified","robustness","significantly","reasoning","available","propositional","independence","databases","graphical","nonmonotonic","maintenance","diagnosis","resembles","specifically","possesses","probabilistic","describes","extension","compactly","difficult","sentences","naturally","constraint","hypotheses","generated","ambiguous","processing","segmentation","handwriting","partially","especially","segmented","recognition","consistency","represent","satisfaction","syntactically","functional","influence","uncertainty","derivation","principles","appearance","determined","technique","description","connected","geometric","formulation","identified","connectedness","photographic","considerations","expressiveness","techniques","arbitrary","calculations","corresponding","registered","annotations","modalities","semantically","annotated","development","potentially","regularities","understanding","utilizing","unsupervised","morphological","interpretability","distributions","automatic","significant","extracted","arrhythmia","heartbeat","consistent","advantages","relabeling","simplification","artifacts","reproduce","individual","descriptions","identification","meaningful","importance","elucidate","formalize","demonstrates","emphasizing","challenge","significance","fundamental","interpretation","knowledge","underlying","potential","abductive","fibrillation","asymptotically","informative","represented","investigated","processes","representations","hyperparameters","recovering","illustrate","estimator","distributed","separation","conducted","unobserved","posterior","addresses","orthogonal","distribution","formulated","according","collapsed","application","posteriori","bernoulli","dimensional","dictionary","appropriate","identifying","component","computations","entropies","character","establishing","developed","retrieval","traditionally","performed","quantifiers","equivalence","important","unavoidable","computational","experiments","compressed","requisite","documents","analytical","computation","quantifier","compression","practiced","conventional","attempted","efficiency","factorizations","tractable","performances","introduces","represents","conditional","incorporate","competitive","assumptions","comparative","semantics","evaluation","empirical","partitioning","regression","advantage" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	kleinberg
# 	regulation
# 	robustify
# 	robustification
# 	advocated
# 	judiciously
# 	corroborate
# 	postulated
# 	preventive
# 	dendrogram
# 	parsimony
# 	reconstructive
# 	unavoidably
# 	surrogates
# 	unconditional
# 	marginally
# 	semiparametric
# 	adjustments
# 	integrators
# 	reconcile
# Some words which never appear in Statistics papers:
# 	propositional
# 	nonmonotonic
# 	satisfaction
# 	syntactically
# 	connectedness
# 	photographic
# 	abductive
# 	quantifiers
# 	cryptanalysis
# 	transformer
# 	vectorized
# 	underrepresented
# 	inflected
# 	autonomously
# 	substrate
# 	antagonistic
# 	certainty
# 	organizations
# 	synchrony
# 	psycholinguistic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0865150158955525e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
